# %% [markdown]
# # Process data

# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import numpy as np
import random
import glob
import umap
import seaborn as sns
import matplotlib.pyplot as plt
from ggplot import *

from numpy.random import seed
randomState = 123
seed(randomState)
# Out:
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp

# %% [markdown]
# ## Data
#
# Data downloaded from ADAGE repository [ADAGE](https://github.com/greenelab/adage).
#
# ```
# data
# ```
# 1. Raw data was downloaded from ArrayExpress using Affymetrix GeneChip
# 2. Use [RMA](https://www.rdocumentation.org/packages/affy/versions/1.50.0/topics/rma) bioconductor library to convert raw array data to log 2 gene expression data.
# 3. Only keep PA genes, remove control genes
#
# ```
# normalized_data
# ```
# 1. Use data from above
# 2. Normalize each gene to be between 0 and 1

# %% [markdown]
# ## About Affymetrix GeneChip processing
#
# **Measurements**
# mRNA samples samples are labeled with flouresence and hybridized to GeneChip probe array.  The probe array is then scanned and the flouresence intensity of each probe (or feature) is measured.  A trasncript is represented by a probe set (~11-20 pairs of probes - see explanation of pairs below).  The probe set intensity forms the expression measure for a given transcript.
#
# **Array Design**
# Two probes: 1) probe is completely complementary to target sequence, perfect match probe (PM) and 2) probe contains a single mismatch to the target sequence in the middle of the probe, mismatch probe(MM).  A probe pair is (PM, MM)
#
# from [The Affymetrix GeneChip Platform: An Overview](https://www.sciencedirect.com/science/article/pii/S0076687906100014?via%3Dihub#fig0001)
#
# **Robust multiarray average (rma)**
#
# 1. Assuming PM = background + signal we want to correct for background signal, returns E[signal|background+signal] assuming signal~exponential and background~normal.
# 2. Use quantile normalization is to make the distribution of probe intensities the same across arrays.  The steps are 1) for each array, rank the probe intensity from lowest to highest, 2) For each array rearrange probe intensity values from lowest to highest, 3) Take the average across arrays for each probe and asssign rank, 4) replace ranks from (1) with mean values.  Example from [Quantile Normalization wiki](https://en.wikipedia.org/wiki/Quantile_normalization)
# 3. Calculating the probe set intensity by averaging PM-MM across probes in probe set and log2 transform, Y.  Fit regression model to Y (probe set intensity) = probe affinity effect + *log scale expression level* + error
#
# from [Exploration, normalization, and summaries of high density oligonucleotide array probe level data](https://academic.oup.com/biostatistics/article/4/2/249/245074)
#
# **Alternative normalization methods**

# %%
# Load arguments
data_file = f"{os.path.dir(os.getcwd())}/data/pseudomonas/Pa_compendium_02.22.2014.pcl"
normalized_data_file = f"{os.path.dir(os.getcwd())}/data/pseudomonas/train_set_normalized.pcl"
metadata_file = f"{os.path.dir(os.getcwd())}/metadata/pseudomonas/sample_annotations.tsv"

# %%
# Read in data
data = pd.read_table(data_file, header=0, sep='\t', index_col=0).T
data.head(5)
# Out:
#                                  PA0001     PA0002    PA0003     PA0004  \
# 05_PA14000-4-2_5-10-07_S2.CEL  9.620090  10.575783  9.296287   9.870074
# 54375-4-05.CEL                 9.327996  10.781977  9.169988  10.269239
# AKGlu_plus_nt_7-8-09_s1.CEL    9.368599  10.596248  9.714517   9.487155
# anaerobic_NO3_1.CEL            9.083292   9.897050  8.068471   7.310218
# anaerobic_NO3_2.CEL            8.854901   9.931392  8.167126   7.526595
#
#                                  PA0005    PA0006    PA0007     PA0008  \
# 05_PA14000-4-2_5-10-07_S2.CEL  8.512268  7.903954  7.039473  10.209826
# 54375-4-05.CEL                 7.237999  7.663758  6.855194   9.631573
# AKGlu_plus_nt_7-8-09_s1.CEL    7.804147  7.681754  6.714411   9.497601
# anaerobic_NO3_1.CEL            6.723634  7.141148  8.492302   7.740717
# anaerobic_NO3_2.CEL            6.864015  7.154523  8.492109   7.716687
#
#                                  PA0009    PA0010    ...        PA5561  \
# 05_PA14000-4-2_5-10-07_S2.CEL  9.784684  5.485688    ...      7.740609
# 54375-4-05.CEL                 9.404465  5.684067    ...      7.127736
# AKGlu_plus_nt_7-8-09_s1.CEL    9.523126  5.766331    ...      7.343241
# anaerobic_NO3_1.CEL            7.640251  5.267993    ...      7.374740
# anaerobic_NO3_2.CEL            7.268094  5.427256    ...      7.425398
#
#                                  PA5562     PA5563     PA5564     PA5565  \
# 05_PA14000-4-2_5-10-07_S2.CEL  9.730384  10.516061  10.639916   9.746849
# 54375-4-05.CEL                 9.687607  10.199612   9.457152   9.318372
# AKGlu_plus_nt_7-8-09_s1.CEL    9.717993  10.419979  10.164667  10.305005
# anaerobic_NO3_1.CEL            8.287819   9.437053   8.936576   9.418147
# anaerobic_NO3_2.CEL            8.588969   9.313851   8.684602   9.272818
#
#                                  PA5566    PA5567     PA5568     PA5569  \
# 05_PA14000-4-2_5-10-07_S2.CEL  5.768592  9.224442  11.512176  12.529719
# 54375-4-05.CEL                 5.523898  7.911031  10.828271  11.597643
# AKGlu_plus_nt_7-8-09_s1.CEL    5.806817  8.575730  10.858250  12.255953
# anaerobic_NO3_1.CEL            5.956482  7.481406   7.687985   9.205525
# anaerobic_NO3_2.CEL            5.729479  7.699086   7.414436   9.363494
#
#                                   PA5570
# 05_PA14000-4-2_5-10-07_S2.CEL  11.804896
# 54375-4-05.CEL                 11.268520
# AKGlu_plus_nt_7-8-09_s1.CEL    11.309662
# anaerobic_NO3_1.CEL             9.395773
# anaerobic_NO3_2.CEL             9.424762
#
# [5 rows x 5549 columns]

# %%
# Read in data
normalized_data = pd.read_table(normalized_data_file, header=0, sep='\t', index_col=0).T
normalized_data.head(5)
# Out:
# Gene_symbol                      PA0001    PA0002    PA0003    PA0004  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.853357  0.725280  0.640617  0.811465
# 54375-4-05.CEL                 0.778790  0.767873  0.614859  0.907865
# AKGlu_plus_nt_7-8-09_s1.CEL    0.789155  0.729508  0.725913  0.718989
# anaerobic_NO3_1.CEL            0.716320  0.585079  0.390211  0.193248
# anaerobic_NO3_2.CEL            0.658015  0.592172  0.410331  0.245504
#
# Gene_symbol                      PA0005    PA0006    PA0007    PA0008  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.694460  0.533958  0.158865  0.889579
# 54375-4-05.CEL                 0.398800  0.460849  0.113876  0.761351
# AKGlu_plus_nt_7-8-09_s1.CEL    0.530160  0.466327  0.079507  0.731643
# anaerobic_NO3_1.CEL            0.279456  0.301781  0.513547  0.342051
# anaerobic_NO3_2.CEL            0.312028  0.305852  0.513499  0.336723
#
# Gene_symbol                      PA0009    PA0010    ...       PA5561  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.884945  0.176558    ...     0.466871
# 54375-4-05.CEL                 0.801740  0.222709    ...     0.352020
# AKGlu_plus_nt_7-8-09_s1.CEL    0.827707  0.241847    ...     0.392405
# anaerobic_NO3_1.CEL            0.415668  0.125914    ...     0.398308
# anaerobic_NO3_2.CEL            0.334226  0.162965    ...     0.407801
#
# Gene_symbol                      PA5562    PA5563    PA5564    PA5565  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.702785  0.790965  0.893249  0.789939
# 54375-4-05.CEL                 0.694387  0.733186  0.639074  0.681204
# AKGlu_plus_nt_7-8-09_s1.CEL    0.700352  0.773422  0.791118  0.931585
# anaerobic_NO3_1.CEL            0.419574  0.593955  0.527203  0.706524
# anaerobic_NO3_2.CEL            0.478697  0.571460  0.473054  0.669643
#
# Gene_symbol                      PA5566    PA5567    PA5568    PA5569  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.164157  0.970470  0.887472  0.900484
# 54375-4-05.CEL                 0.110301  0.619554  0.747656  0.749893
# AKGlu_plus_nt_7-8-09_s1.CEL    0.172570  0.797148  0.753785  0.856253
# anaerobic_NO3_1.CEL            0.205510  0.504767  0.105662  0.363409
# anaerobic_NO3_2.CEL            0.155548  0.562927  0.049738  0.388931
#
# Gene_symbol                      PA5570
# 05_PA14000-4-2_5-10-07_S2.CEL  0.880012
# 54375-4-05.CEL                 0.805374
# AKGlu_plus_nt_7-8-09_s1.CEL    0.811099
# anaerobic_NO3_1.CEL            0.544780
# anaerobic_NO3_2.CEL            0.548814
#
# [5 rows x 5549 columns]

# %%
# Read in metadata
metadata = pd.read_table(metadata_file, header=0, sep='\t', index_col='ml_data_source')
metadata
# Out:
#                                          experiment  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL           E-GEOD-46947
# GSM1141729_PA01_none_PC_.CEL           E-GEOD-46947
# GSM1608059_Planktonic_1.CEL            E-GEOD-65882
# GSM1608060_Planktonic_2.CEL            E-GEOD-65882
# GSM1608061_Planktonic_3.CEL            E-GEOD-65882
# NaN                                                                    GSE3090GSM68695
# aerobic_NO3_1.CEL                                                        aerobic_NO3_1
# aerobic_NO3_2.CEL                                                        aerobic_NO3_2
# anaerobic_NO3_1.CEL                                                    anaerobic_NO3_1
# anaerobic_NO3_2.CEL                                                    anaerobic_NO3_2
# DC2.CEL                                                         Pseudomonas aeruginosa
# DB1.CEL                                Pseudomonas aeruginosa__S:BioSource:MEXP:168319
# DC3.CEL                                Pseudomonas aeruginosa__S:BioSource:MEXP:168323
# DB3.CEL                                Pseudomonas aeruginosa__S:BioSource:MEXP:168320
# DC1.CEL                                Pseudomonas aeruginosa__S:BioSource:MEXP:168321
#
#                                                                              description  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL           Pseudomonas aeruginosa PAO1 LB aerated  5 h wi...
# GSM1141729_PA01_none_PC_.CEL                 Pseudomonas aeruginosa PAO1 LB aerated  5 h
# GSM1608059_Planktonic_1.CEL                                    PAO1 WT. Planktonic. Rep1
# GSM1608060_Planktonic_2.CEL                                    PAO1 WT. Planktonic. Rep2
# GSM1608061_Planktonic_3.CEL                                    PAO1 WT. Planktonic. Rep3
# GSM1608062_Planktonic_4.CEL                                    PAO1 WT. Planktonic. Rep4
# GSM1608067_Biofilm+12hrcipro_rep1.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608068_Biofilm+12hrcipro_rep2.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608069_Biofilm+12hrcipro_rep3.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608070_Biofilm+12hrtobra_rep1.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608071_Biofilm+12hrtobra_rep2.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608072_Biofilm+12hrtobra_rep3.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608067_Biofilm+12hrcipro_rep1.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608068_Biofilm+12hrcipro_rep2.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608069_Biofilm+12hrcipro_rep3.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608070_Biofilm+12hrtobra_rep1.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608071_Biofilm+12hrtobra_rep2.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608072_Biofilm+12hrtobra_rep3.CEL  P. aeruginosa PAO1, cells grown 72 hours in a ...
# GSM1608059_Planktonic_1.CEL                                    PAO1 WT. Planktonic. Rep1
# GSM1608060_Planktonic_2.CEL                                    PAO1 WT. Planktonic. Rep2
# GSM1608061_Planktonic_3.CEL                                    PAO1 WT. Planktonic. Rep3
# GSM1608062_Planktonic_4.CEL                                    PAO1 WT. Planktonic. Rep4
# GSM1310895_PA14_wild-type.CEL                                PA14 wild-type without H2O2
# GSM1310896_PA14_lasR_rhlR.CEL                               PA14 lasR rhlR without H2O2.
# GSM1310897_PA14_wild-type_+H2O2.CEL                            PA14 wild-type with H2O2.
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL                            PA14 lasR rhlR with H2O2.
# Overhage13001_(Pae_G1a).CEL            PA14 wt 1  was spotted on BM2-swarm plates con...
# Overhage13002_(Pae_G1a).CEL            PA14 wt 2  was spotted on BM2-swarm plates con...
# Overhage13003_(Pae_G1a).CEL            PA14 PA4398 mutant strain was spotted on BM2-s...
# Overhage13004_(Pae_G1a).CEL            PA14 PA4398 mutant strain was spotted on BM2-s...
# ...                                                                                  ...
# NaN                                                            PAO1 ΔPA2384; replicate 2
# NaN                                                                 PAO1 WT; replicate 2
# MSC_01.CEL                             Pseudomonas aeruginosa PAO1 WT, no acyl-HSL, rep1
# MSC_02.CEL                             Pseudomonas aeruginosa PAO1 WT, no acyl-HSL, rep2
# MSC_03.CEL                             Pseudomonas aeruginosa PAO1 WT, plus 2 μM 3OC1...
# MSC_04.CEL                             Pseudomonas aeruginosa PAO1 WT, plus 2 μM 3OC1...
# MSC_05.CEL                             Pseudomonas aeruginosa PAO1 ∆lasR ∆rhlR, chrom...
# MSC_06.CEL                             Pseudomonas aeruginosa PAO1 ∆lasR ∆rhlR, chrom...
# MSC_07.CEL                             Pseudomonas aeruginosa PAO1 ∆lasR ∆rhlR  chrom...
# MSC_08.CEL                             Pseudomonas aeruginosa PAO1 ∆lasR ∆rhlR  chrom...
# MSC_09.CEL                             Pseudomonas aeruginosa PAO1 ∆rpoS chromosomal ...
# MSC_10.CEL                             Pseudomonas aeruginosa PAO1 ∆rpoS chromosomal ...
# NaN                                                PAO1 with 10 mM H2O2 for 20 min, Rep1
# NaN                                                PAO1 with 10 mM H2O2 for 20 min, Rep2
# NaN                                                PAO1 with 10 mM H2O2 for 20 min, Rep3
# NaN                                                PAO1 with 10 mM H2O2 for 20 min, Rep4
# NaN                                                PAO1 with 10 mM H2O2 for 20 min, Rep5
# NaN                                                            PAO1 WT. Planktonic. Rep1
# NaN                                                            PAO1 WT. Planktonic. Rep2
# NaN                                                            PAO1 WT. Planktonic. Rep3
# NaN                                                            PAO1 WT. Planktonic. Rep4
# aerobic_NO3_1.CEL                      PA14 WT grown planktonically with aeration in ...
# aerobic_NO3_2.CEL                      PA14 WT grown planktonically with aeration in ...
# anaerobic_NO3_1.CEL                    PA14 WT grown planktonically under anaerobic c...
# anaerobic_NO3_2.CEL                    PA14 WT grown planktonically under anaerobic c...
# DC2.CEL                                    PAO1 biofilm in minimal medium with glutamate
# DB1.CEL                                PAO1 planktonic dispersed from biofilm (high g...
# DC3.CEL                                PAO1 planktonic dispersed from biofilm (high g...
# DB3.CEL                                    PAO1 biofilm in minimal medium with glutamate
# DC1.CEL                                PAO1 planktonic dispersed from biofilm (high g...
#
#                                       nucleic_acid  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                   RNA
# GSM1141729_PA01_none_PC_.CEL                   RNA
# GSM1608059_Planktonic_1.CEL                    RNA
# GSM1608060_Planktonic_2.CEL                    RNA
# GSM1608061_Planktonic_3.CEL                    RNA
# GSM1608062_Planktonic_4.CEL                    RNA
# GSM1608067_Biofilm+12hrcipro_rep1.CEL          RNA
# GSM1608068_Biofilm+12hrcipro_rep2.CEL          RNA
# GSM1608069_Biofilm+12hrcipro_rep3.CEL          RNA
# GSM1608070_Biofilm+12hrtobra_rep1.CEL          RNA
# GSM1608071_Biofilm+12hrtobra_rep2.CEL          RNA
# GSM1608072_Biofilm+12hrtobra_rep3.CEL          RNA
# GSM1608067_Biofilm+12hrcipro_rep1.CEL          RNA
# GSM1608068_Biofilm+12hrcipro_rep2.CEL          RNA
# GSM1608069_Biofilm+12hrcipro_rep3.CEL          RNA
# GSM1608070_Biofilm+12hrtobra_rep1.CEL          RNA
# GSM1608071_Biofilm+12hrtobra_rep2.CEL          RNA
# GSM1608072_Biofilm+12hrtobra_rep3.CEL          RNA
# GSM1608059_Planktonic_1.CEL                    RNA
# GSM1608060_Planktonic_2.CEL                    RNA
# GSM1608061_Planktonic_3.CEL                    RNA
# GSM1608062_Planktonic_4.CEL                    RNA
# GSM1310895_PA14_wild-type.CEL                  RNA
# GSM1310896_PA14_lasR_rhlR.CEL                  RNA
# GSM1310897_PA14_wild-type_+H2O2.CEL            RNA
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL            RNA
# Overhage13001_(Pae_G1a).CEL                    RNA
# Overhage13002_(Pae_G1a).CEL                    RNA
# Overhage13003_(Pae_G1a).CEL                    RNA
# Overhage13004_(Pae_G1a).CEL                    RNA
# ...                                            ...
# NaN                                            RNA
# NaN                                            RNA
# MSC_01.CEL                                     RNA
# MSC_02.CEL                                     RNA
# MSC_03.CEL                                     RNA
# MSC_04.CEL                                     RNA
# MSC_05.CEL                                     RNA
# MSC_06.CEL                                     RNA
# MSC_07.CEL                                     RNA
# MSC_08.CEL                                     RNA
# MSC_09.CEL                                     RNA
# MSC_10.CEL                                     RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# NaN                                            RNA
# aerobic_NO3_1.CEL                              RNA
# aerobic_NO3_2.CEL                              RNA
# anaerobic_NO3_1.CEL                            RNA
# anaerobic_NO3_2.CEL                            RNA
# DC2.CEL                                        RNA
# DB1.CEL                                        RNA
# DC3.CEL                                        RNA
# DB3.CEL                                        RNA
# DC1.CEL                                        RNA
#
#                                                                                   medium  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                                                          LB
# GSM1141729_PA01_none_PC_.CEL                                                          LB
# GSM1608059_Planktonic_1.CEL                                   PBM plus 1 g / L glucose.
# GSM1608060_Planktonic_2.CEL                                   PBM plus 1 g / L glucose.
# GSM1608061_Planktonic_3.CEL                                   PBM plus 1 g / L glucose.
# GSM1608062_Planktonic_4.CEL                                   PBM plus 1 g / L glucose.
# GSM1608067_Biofilm+12hrcipro_rep1.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608068_Biofilm+12hrcipro_rep2.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608069_Biofilm+12hrcipro_rep3.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608070_Biofilm+12hrtobra_rep1.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608071_Biofilm+12hrtobra_rep2.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608072_Biofilm+12hrtobra_rep3.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608067_Biofilm+12hrcipro_rep1.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608068_Biofilm+12hrcipro_rep2.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608069_Biofilm+12hrcipro_rep3.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608070_Biofilm+12hrtobra_rep1.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608071_Biofilm+12hrtobra_rep2.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608072_Biofilm+12hrtobra_rep3.CEL              PBM supplemented with 0.2 g/L glucose
# GSM1608059_Planktonic_1.CEL                                   PBM plus 1 g / L glucose.
# GSM1608060_Planktonic_2.CEL                                   PBM plus 1 g / L glucose.
# GSM1608061_Planktonic_3.CEL                                   PBM plus 1 g / L glucose.
# GSM1608062_Planktonic_4.CEL                                   PBM plus 1 g / L glucose.
# GSM1310895_PA14_wild-type.CEL                                                         LB
# GSM1310896_PA14_lasR_rhlR.CEL                                                         LB
# GSM1310897_PA14_wild-type_+H2O2.CEL                                                   LB
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL                                                   LB
# Overhage13001_(Pae_G1a).CEL                                                          BM2
# Overhage13002_(Pae_G1a).CEL                                                          BM2
# Overhage13003_(Pae_G1a).CEL                                                          BM2
# Overhage13004_(Pae_G1a).CEL                                                          BM2
# ...                                                                                  ...
# NaN                                                        Iron limited minimal medium C
# NaN                                                        Iron limited minimal medium C
# MSC_01.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_02.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_03.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_04.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_05.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_06.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_07.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_08.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_09.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# MSC_10.CEL                             LB buffered with 50 mM 3-(N-morpholino) propan...
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# NaN                                                                                   LB
# aerobic_NO3_1.CEL                                 MOPS with 10% CF sputum and 100mM KNO3
# aerobic_NO3_2.CEL                                 MOPS with 10% CF sputum and 100mM KNO3
# anaerobic_NO3_1.CEL                               MOPS with 10% CF sputum and 100mM KNO3
# anaerobic_NO3_2.CEL                               MOPS with 10% CF sputum and 100mM KNO3
# DC2.CEL                                             Minimal medium with 1.8 mM glutamate
# DB1.CEL                                            Minimal medium with 19.8 mM glutamate
# DC3.CEL                                             Minimal medium with 1.8 mM glutamate
# DB3.CEL                                            Minimal medium with 19.8 mM glutamate
# DC1.CEL                                            Minimal medium with 19.8 mM glutamate
#
#                                            genotype        od  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                    NaN       NaN
# GSM1141729_PA01_none_PC_.CEL                    NaN       NaN
# GSM1608059_Planktonic_1.CEL                      WT      0.26
# GSM1608060_Planktonic_2.CEL                      WT      0.26
# GSM1608061_Planktonic_3.CEL                      WT      0.26
# GSM1608062_Planktonic_4.CEL                      WT      0.26
# GSM1608067_Biofilm+12hrcipro_rep1.CEL            WT       NaN
# GSM1608068_Biofilm+12hrcipro_rep2.CEL            WT       NaN
# GSM1608069_Biofilm+12hrcipro_rep3.CEL            WT       NaN
# GSM1608070_Biofilm+12hrtobra_rep1.CEL            WT       NaN
# GSM1608071_Biofilm+12hrtobra_rep2.CEL            WT       NaN
# GSM1608072_Biofilm+12hrtobra_rep3.CEL            WT       NaN
# GSM1608067_Biofilm+12hrcipro_rep1.CEL            WT       NaN
# GSM1608068_Biofilm+12hrcipro_rep2.CEL            WT       NaN
# GSM1608069_Biofilm+12hrcipro_rep3.CEL            WT       NaN
# GSM1608070_Biofilm+12hrtobra_rep1.CEL            WT       NaN
# GSM1608071_Biofilm+12hrtobra_rep2.CEL            WT       NaN
# GSM1608072_Biofilm+12hrtobra_rep3.CEL            WT       NaN
# GSM1608059_Planktonic_1.CEL                      WT      0.26
# GSM1608060_Planktonic_2.CEL                      WT      0.26
# GSM1608061_Planktonic_3.CEL                      WT      0.26
# GSM1608062_Planktonic_4.CEL                      WT      0.26
# GSM1310895_PA14_wild-type.CEL                    WT       1.5
# GSM1310896_PA14_lasR_rhlR.CEL             ∆lasR∆rhR       1.5
# GSM1310897_PA14_wild-type_+H2O2.CEL              WT       1.5
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL       ∆lasR∆rhR       1.5
# Overhage13001_(Pae_G1a).CEL                      WT  20 hours
# Overhage13002_(Pae_G1a).CEL                      WT  20 hours
# Overhage13003_(Pae_G1a).CEL                 ΔPA4398  20 hours
# Overhage13004_(Pae_G1a).CEL                 ΔPA4398  20 hours
# ...                                             ...       ...
# NaN                                         ΔPA2384       2.1
# NaN                                              WT       2.1
# MSC_01.CEL                                       WT       NaN
# MSC_02.CEL                                       WT       NaN
# MSC_03.CEL                                       WT       NaN
# MSC_04.CEL                                       WT       NaN
# MSC_05.CEL                             ∆lasR ∆rhlR        NaN
# MSC_06.CEL                             ∆lasR ∆rhlR        NaN
# MSC_07.CEL                             ∆lasR ∆rhlR        NaN
# MSC_08.CEL                             ∆lasR ∆rhlR        NaN
# MSC_09.CEL                                    ∆rpoS       NaN
# MSC_10.CEL                                    ∆rpoS       NaN
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# NaN                                              WT       0.8
# aerobic_NO3_1.CEL                                WT       0.1
# aerobic_NO3_2.CEL                                WT       0.1
# anaerobic_NO3_1.CEL                              WT       0.1
# anaerobic_NO3_2.CEL                              WT       0.1
# DC2.CEL                                         NaN       NaN
# DB1.CEL                                         NaN       NaN
# DC3.CEL                                         NaN       NaN
# DB3.CEL                                         NaN       NaN
# DC1.CEL                                         NaN       NaN
#
#                                       growth_setting_1  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                planktonic
# GSM1141729_PA01_none_PC_.CEL                planktonic
# GSM1608059_Planktonic_1.CEL                Planktonic
# GSM1608060_Planktonic_2.CEL                Planktonic
# GSM1608061_Planktonic_3.CEL                Planktonic
# GSM1608062_Planktonic_4.CEL                Planktonic
# GSM1608067_Biofilm+12hrcipro_rep1.CEL          Biofilm
# GSM1608068_Biofilm+12hrcipro_rep2.CEL          Biofilm
# GSM1608069_Biofilm+12hrcipro_rep3.CEL          Biofilm
# GSM1608070_Biofilm+12hrtobra_rep1.CEL          Biofilm
# GSM1608071_Biofilm+12hrtobra_rep2.CEL          Biofilm
# GSM1608072_Biofilm+12hrtobra_rep3.CEL          Biofilm
# GSM1608067_Biofilm+12hrcipro_rep1.CEL          Biofilm
# GSM1608068_Biofilm+12hrcipro_rep2.CEL          Biofilm
# GSM1608069_Biofilm+12hrcipro_rep3.CEL          Biofilm
# GSM1608070_Biofilm+12hrtobra_rep1.CEL          Biofilm
# GSM1608071_Biofilm+12hrtobra_rep2.CEL          Biofilm
# GSM1608072_Biofilm+12hrtobra_rep3.CEL          Biofilm
# GSM1608059_Planktonic_1.CEL                Planktonic
# GSM1608060_Planktonic_2.CEL                Planktonic
# GSM1608061_Planktonic_3.CEL                Planktonic
# GSM1608062_Planktonic_4.CEL                Planktonic
# GSM1310895_PA14_wild-type.CEL               Planktonic
# GSM1310896_PA14_lasR_rhlR.CEL               Planktonic
# GSM1310897_PA14_wild-type_+H2O2.CEL         Planktonic
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL         Planktonic
# Overhage13001_(Pae_G1a).CEL                      Swarm
# Overhage13002_(Pae_G1a).CEL                      Swarm
# Overhage13003_(Pae_G1a).CEL                      Swarm
# Overhage13004_(Pae_G1a).CEL                      Swarm
# ...                                                ...
# NaN                                         Planktonic
# NaN                                         Planktonic
# MSC_01.CEL                                  Planktonic
# GSM1608059_Planktonic_1.CEL                                                      NaN
# GSM1608060_Planktonic_2.CEL                                                      NaN
# GSM1608061_Planktonic_3.CEL                                                      NaN
# GSM1608062_Planktonic_4.CEL                                                      NaN
# GSM1310895_PA14_wild-type.CEL                                                    NaN
# GSM1310896_PA14_lasR_rhlR.CEL                                                    NaN
# GSM1310897_PA14_wild-type_+H2O2.CEL                                       80 mM H2O2
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL                                       80 mM H2O2
# Overhage13001_(Pae_G1a).CEL                                                      NaN
# Overhage13002_(Pae_G1a).CEL                                                      NaN
# Overhage13003_(Pae_G1a).CEL                                                      NaN
# Overhage13004_(Pae_G1a).CEL                                                      NaN
# ...                                                                              ...
# NaN                                                                              NaN
# NaN                                                                              NaN
# MSC_01.CEL                                                                       NaN
# MSC_02.CEL                                                                       NaN
# MSC_03.CEL                                                                       NaN
# MSC_04.CEL                                                                       NaN
# MSC_05.CEL                                           unknown L- arabinose treatment
# MSC_06.CEL                                           unknown L- arabinose treatment
# MSC_07.CEL                                           unknown L- arabinose treatment
# MSC_08.CEL                                           unknown L- arabinose treatment
# MSC_09.CEL                                           unknown L- arabinose treatment
# MSC_10.CEL                                           unknown L- arabinose treatment
# NaN                                                           1 mM hydrogen peroxide
# NaN                                                           1 mM hydrogen peroxide
# NaN                                                           1 mM hydrogen peroxide
# NaN                                                           1 mM hydrogen peroxide
# NaN                                                           1 mM hydrogen peroxide
# NaN                                                                              NaN
# NaN                                                                              NaN
# NaN                                                                              NaN
# NaN                                                                              NaN
# aerobic_NO3_1.CEL                                                                NaN
# aerobic_NO3_2.CEL                                                                NaN
# anaerobic_NO3_1.CEL                                                 anaerobic growth
# anaerobic_NO3_2.CEL                                                 anaerobic growth
# DC2.CEL                                                                          NaN
# DB1.CEL                                                                          NaN
# DC3.CEL                                                                          NaN
# DB3.CEL                                                                          NaN
# DC1.CEL                                                                          NaN
#
#                                                                         additional_notes  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                                                Grown for 5h
# GSM1141729_PA01_none_PC_.CEL                                                Grown for 5h
# GSM1608059_Planktonic_1.CEL                                      Grown shaking at 200rpm
# GSM1608060_Planktonic_2.CEL                                      Grown shaking at 200rpm
# GSM1608061_Planktonic_3.CEL                                      Grown shaking at 200rpm
# GSM1608062_Planktonic_4.CEL                                      Grown shaking at 200rpm
# GSM1608067_Biofilm+12hrcipro_rep1.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608068_Biofilm+12hrcipro_rep2.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608069_Biofilm+12hrcipro_rep3.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608070_Biofilm+12hrtobra_rep1.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608071_Biofilm+12hrtobra_rep2.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608072_Biofilm+12hrtobra_rep3.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608067_Biofilm+12hrcipro_rep1.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608068_Biofilm+12hrcipro_rep2.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608069_Biofilm+12hrcipro_rep3.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608070_Biofilm+12hrtobra_rep1.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608071_Biofilm+12hrtobra_rep2.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608072_Biofilm+12hrtobra_rep3.CEL  12 hours; stainless steel slides; 10o incline;...
# GSM1608059_Planktonic_1.CEL                                      Grown shaking at 200rpm
# GSM1608060_Planktonic_2.CEL                                      Grown shaking at 200rpm
# GSM1608061_Planktonic_3.CEL                                      Grown shaking at 200rpm
# GSM1608062_Planktonic_4.CEL                                      Grown shaking at 200rpm
# GSM1310895_PA14_wild-type.CEL                                                        NaN
# GSM1310896_PA14_lasR_rhlR.CEL                                                        NaN
# GSM1310897_PA14_wild-type_+H2O2.CEL                                      30 min exposure
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL                                      30 min exposure
# Overhage13001_(Pae_G1a).CEL            BM2-swarm plates containing 0.1 % (wt/vol) cas...
# Overhage13002_(Pae_G1a).CEL            BM2-swarm plates containing 0.1 % (wt/vol) cas...
# Overhage13003_(Pae_G1a).CEL            BM2-swarm plates containing 0.1 % (wt/vol) cas...
# Overhage13004_(Pae_G1a).CEL            BM2-swarm plates containing 0.1 % (wt/vol) cas...
# ...                                                                                  ...
# NaN                                                   Bioreactor system; 500 rpm; pH 7.0
# NaN                                                   Bioreactor system; 500 rpm; pH 7.0
# MSC_01.CEL                                                                           NaN
# MSC_02.CEL                                                                           NaN
# MSC_03.CEL                                                                           NaN
# MSC_04.CEL                                                                           NaN
# MSC_05.CEL                                                                           NaN
# MSC_06.CEL                                                                           NaN
# MSC_07.CEL                                                                           NaN
# MSC_08.CEL                                                                           NaN
# MSC_09.CEL                                                                           NaN
# MSC_10.CEL                                                                           NaN
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# NaN                                               Grown shaking at 250rpm. 20 m exposure
# aerobic_NO3_1.CEL                                                                    NaN
# aerobic_NO3_2.CEL                                                                    NaN
# anaerobic_NO3_1.CEL                                                                  NaN
# anaerobic_NO3_2.CEL                                                                  NaN
# DC2.CEL                                                                              NaN
# DB1.CEL                                                                              NaN
# DC3.CEL                                                                              NaN
# DB3.CEL                                                                              NaN
# DC1.CEL                                                                              NaN
#
#                                       variant_phenotype abx_marker  \
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                        NaN        NaN
# GSM1141729_PA01_none_PC_.CEL                        NaN        NaN
# GSM1608059_Planktonic_1.CEL                         NaN        NaN
# GSM1608060_Planktonic_2.CEL                         NaN        NaN
# GSM1608061_Planktonic_3.CEL                         NaN        NaN
# GSM1608062_Planktonic_4.CEL                         NaN        NaN
# GSM1608067_Biofilm+12hrcipro_rep1.CEL               NaN        NaN
# GSM1608068_Biofilm+12hrcipro_rep2.CEL               NaN        NaN
# GSM1608069_Biofilm+12hrcipro_rep3.CEL               NaN        NaN
# GSM1608070_Biofilm+12hrtobra_rep1.CEL               NaN        NaN
# GSM1608071_Biofilm+12hrtobra_rep2.CEL               NaN        NaN
# GSM1608072_Biofilm+12hrtobra_rep3.CEL               NaN        NaN
# GSM1608067_Biofilm+12hrcipro_rep1.CEL               NaN        NaN
# GSM1608068_Biofilm+12hrcipro_rep2.CEL               NaN        NaN
# GSM1608069_Biofilm+12hrcipro_rep3.CEL               NaN        NaN
# GSM1608070_Biofilm+12hrtobra_rep1.CEL               NaN        NaN
# GSM1608071_Biofilm+12hrtobra_rep2.CEL               NaN        NaN
# GSM1608072_Biofilm+12hrtobra_rep3.CEL               NaN        NaN
# GSM1608059_Planktonic_1.CEL                         NaN        NaN
# GSM1608060_Planktonic_2.CEL                         NaN        NaN
# GSM1608061_Planktonic_3.CEL                         NaN        NaN
# GSM1608062_Planktonic_4.CEL                         NaN        NaN
# GSM1310895_PA14_wild-type.CEL                       NaN        NaN
# GSM1310896_PA14_lasR_rhlR.CEL                       NaN        NaN
# GSM1310897_PA14_wild-type_+H2O2.CEL                 NaN        NaN
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL                 NaN        NaN
# Overhage13001_(Pae_G1a).CEL                         NaN        NaN
# Overhage13002_(Pae_G1a).CEL                         NaN        NaN
# Overhage13003_(Pae_G1a).CEL                         NaN        NaN
# Overhage13004_(Pae_G1a).CEL                         NaN        NaN
# ...                                                 ...        ...
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# MSC_01.CEL                                          NaN        NaN
# MSC_02.CEL                                          NaN        NaN
# MSC_03.CEL                                          NaN        NaN
# MSC_04.CEL                                          NaN        NaN
# MSC_05.CEL                                          NaN        NaN
# MSC_06.CEL                                          NaN        NaN
# MSC_07.CEL                                          NaN        NaN
# MSC_08.CEL                                          NaN        NaN
# MSC_09.CEL                                          NaN        NaN
# MSC_10.CEL                                          NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# NaN                                                 NaN        NaN
# aerobic_NO3_1.CEL                                   NaN        NaN
# aerobic_NO3_2.CEL                                   NaN        NaN
# anaerobic_NO3_1.CEL                                 NaN        NaN
# anaerobic_NO3_2.CEL                                 NaN        NaN
# DC2.CEL                                             NaN        NaN
# DB1.CEL                                             NaN        NaN
# DC3.CEL                                             NaN        NaN
# DB3.CEL                                             NaN        NaN
# DC1.CEL                                             NaN        NaN
#
#                                       biotic_int_lv_2 biotic_int_lv_1
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                      NaN             NaN
# GSM1141729_PA01_none_PC_.CEL                      NaN             NaN
# GSM1608059_Planktonic_1.CEL                       NaN             NaN
# GSM1608060_Planktonic_2.CEL                       NaN             NaN
# GSM1608061_Planktonic_3.CEL                       NaN             NaN
# GSM1608062_Planktonic_4.CEL                       NaN             NaN
# GSM1608067_Biofilm+12hrcipro_rep1.CEL             NaN             NaN
# GSM1608068_Biofilm+12hrcipro_rep2.CEL             NaN             NaN
# GSM1608069_Biofilm+12hrcipro_rep3.CEL             NaN             NaN
# GSM1608070_Biofilm+12hrtobra_rep1.CEL             NaN             NaN
# GSM1608071_Biofilm+12hrtobra_rep2.CEL             NaN             NaN
# GSM1608072_Biofilm+12hrtobra_rep3.CEL             NaN             NaN
# GSM1608067_Biofilm+12hrcipro_rep1.CEL             NaN             NaN
# GSM1608068_Biofilm+12hrcipro_rep2.CEL             NaN             NaN
# GSM1608069_Biofilm+12hrcipro_rep3.CEL             NaN             NaN
# GSM1608070_Biofilm+12hrtobra_rep1.CEL             NaN             NaN
# GSM1608071_Biofilm+12hrtobra_rep2.CEL             NaN             NaN
# GSM1608072_Biofilm+12hrtobra_rep3.CEL             NaN             NaN
# GSM1608059_Planktonic_1.CEL                       NaN             NaN
# GSM1608060_Planktonic_2.CEL                       NaN             NaN
# GSM1608061_Planktonic_3.CEL                       NaN             NaN
# GSM1608062_Planktonic_4.CEL                       NaN             NaN
# GSM1310895_PA14_wild-type.CEL                     NaN             NaN
# GSM1310896_PA14_lasR_rhlR.CEL                     NaN             NaN
# GSM1310897_PA14_wild-type_+H2O2.CEL               NaN             NaN
# GSM1310898_PA14_lasR_rhlR_+H2O2.CEL               NaN             NaN
# Overhage13001_(Pae_G1a).CEL                       NaN             NaN
# Overhage13002_(Pae_G1a).CEL                       NaN             NaN
# Overhage13003_(Pae_G1a).CEL                       NaN             NaN
# Overhage13004_(Pae_G1a).CEL                       NaN             NaN
# ...                                               ...             ...
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# MSC_01.CEL                                        NaN             NaN
# MSC_02.CEL                                        NaN             NaN
# MSC_03.CEL                                        NaN             NaN
# MSC_04.CEL                                        NaN             NaN
# MSC_05.CEL                                        NaN             NaN
# MSC_06.CEL                                        NaN             NaN
# MSC_07.CEL                                        NaN             NaN
# MSC_08.CEL                                        NaN             NaN
# MSC_09.CEL                                        NaN             NaN
# MSC_10.CEL                                        NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# NaN                                               NaN             NaN
# aerobic_NO3_1.CEL                                 NaN             NaN
# aerobic_NO3_2.CEL                                 NaN             NaN
# anaerobic_NO3_1.CEL                               NaN             NaN
# anaerobic_NO3_2.CEL                               NaN             NaN
# DC2.CEL                                           NaN             NaN
# DB1.CEL                                           NaN             NaN
# DC3.CEL                                           NaN             NaN
# DB3.CEL                                           NaN             NaN
# DC1.CEL                                           NaN             NaN
#
# [1217 rows x 17 columns]

# %% [markdown]
# ## Select metadata field

# %%
# Select metadata field
# Choices:  medium
#           strain
#           growth_setting_1
#           experiment
metadata_field = 'growth_setting_1'
metadata_selected = metadata[metadata_field].to_frame()

metadata_selected.head(5)
# Out:
#                              growth_setting_1
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL       planktonic
# GSM1141729_PA01_none_PC_.CEL       planktonic
# GSM1608059_Planktonic_1.CEL       Planktonic
# GSM1608060_Planktonic_2.CEL       Planktonic
# GSM1608061_Planktonic_3.CEL       Planktonic

# %%
# Select subset of values within metadata field
if metadata_field == 'experiment':
    metadata_selected_labeled = metadata_selected

if metadata_field == 'strain':
    values = ['PAO1', 'PA14', 'CF sputum isolate']
    # Re-label metadata field based on subset of values
    metadata_vector = metadata[metadata_field]

    sample_id = metadata_selected.index

    metadata_selected_labeled = metadata_selected.assign(
        strain=(
            list( 
                map(
                    lambda x:
                    values[0] if x.lower().strip() == values[0].lower() 
                    else values[1] if x.lower().strip() == values[1].lower()
                    else values[2] if x.lower().strip() == values[2].lower()
                    else 'NA',
                    metadata_vector
                )      
            )
        )
    )
    metadata_selected_labeled = metadata_selected_labeled.astype({metadata_field: str})
    
if metadata_field == 'growth_setting_1':
    values = ['Planktonic', 'Biofilm', 'Colony', 'Swarm']
    
    # Re-label metadata field based on subset of values
    metadata_vector = metadata[metadata_field]

    sample_id = metadata_selected.index

    metadata_selected_labeled = metadata_selected.assign(
        growth_setting_1=(
            list( 
                map(
                    lambda x:
                    'NA' if type(x) == float
                    else values[0] if x.lower().strip() == values[0].lower() 
                    else values[1] if x.lower().strip() == values[1].lower()
                    else values[2] if x.lower().strip() == values[2].lower()
                    else values[3] if x.lower().strip() == values[3].lower()
                    else 'NA',
                    metadata_vector
                )      
            )
        )
    )
    metadata_selected_labeled = metadata_selected_labeled.astype({metadata_field: str})
    
if metadata_field == 'medium':
    values = ['LB', 'PIA', 'sputum', 'pyruvate', 'casamino acids']
    
    # Re-label metadata field based on subset of values
    metadata_vector = metadata[metadata_field]

    sample_id = metadata_selected.index

    metadata_selected_labeled = metadata_selected.assign(
        medium=(
            list( 
                map(
                    lambda x:
                    values[0] if values[0].lower() in x.lower().strip()
                    else values[1] if x.lower().strip() == values[1].lower()
                    else values[2] if values[2].lower() in x.lower().strip()
                    else values[3] if values[3].lower() in x.lower().strip()
                    else values[4] if values[4].lower() in x.lower().strip()
                    else 'NA',
                    metadata_vector
                )      
            )
        )
    )
    metadata_selected_labeled = metadata_selected_labeled.astype({metadata_field: str})

# %%
# Get counts
metadata_selected_labeled[metadata_selected_labeled[metadata_field] == 'sputum'].shape
# Out:
# (0, 1)

# %%
metadata_selected_labeled.head(10)
# Out:
#                                       growth_setting_1
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                Planktonic
# GSM1141729_PA01_none_PC_.CEL                Planktonic
# GSM1608059_Planktonic_1.CEL                 Planktonic
# GSM1608060_Planktonic_2.CEL                 Planktonic
# GSM1608061_Planktonic_3.CEL                 Planktonic
# GSM1608062_Planktonic_4.CEL                 Planktonic
# GSM1608067_Biofilm+12hrcipro_rep1.CEL          Biofilm
# GSM1608068_Biofilm+12hrcipro_rep2.CEL          Biofilm
# GSM1608069_Biofilm+12hrcipro_rep3.CEL          Biofilm
# GSM1608070_Biofilm+12hrtobra_rep1.CEL          Biofilm

# %%
metadata_selected.head(10)
# Out:
#                                       growth_setting_1
# ml_data_source
# GSM1141730_PA01_ZnO_PZO_.CEL                planktonic
# GSM1141729_PA01_none_PC_.CEL                planktonic
# GSM1608059_Planktonic_1.CEL                Planktonic
# GSM1608060_Planktonic_2.CEL                Planktonic
# GSM1608061_Planktonic_3.CEL                Planktonic
# GSM1608062_Planktonic_4.CEL                Planktonic
# GSM1608067_Biofilm+12hrcipro_rep1.CEL          Biofilm
# GSM1608068_Biofilm+12hrcipro_rep2.CEL          Biofilm
# GSM1608069_Biofilm+12hrcipro_rep3.CEL          Biofilm
# GSM1608070_Biofilm+12hrtobra_rep1.CEL          Biofilm

# %% [markdown]
# ## Plot RMA normalized data

# %%
data_labeled = data.merge(
    metadata_selected_labeled,
    left_index=True,
    right_index=True,
    how='inner')

print(data_labeled.shape)
data_labeled.head(5)
# Out:
# (989, 5550)
#                                  PA0001     PA0002    PA0003     PA0004  \
# 05_PA14000-4-2_5-10-07_S2.CEL  9.620090  10.575783  9.296287   9.870074
# 54375-4-05.CEL                 9.327996  10.781977  9.169988  10.269239
# AKGlu_plus_nt_7-8-09_s1.CEL    9.368599  10.596248  9.714517   9.487155
# DB1.CEL                        7.280984   9.297857  8.098532   8.292351
# DB3.CEL                        7.534696   9.257259  7.291374   8.364399
#
#                                  PA0005    PA0006    PA0007     PA0008  \
# 05_PA14000-4-2_5-10-07_S2.CEL  8.512268  7.903954  7.039473  10.209826
# 54375-4-05.CEL                 7.237999  7.663758  6.855194   9.631573
# AKGlu_plus_nt_7-8-09_s1.CEL    7.804147  7.681754  6.714411   9.497601
# DB1.CEL                        7.238569  7.397761  9.061829   8.767567
# DB3.CEL                        6.966678  7.396866  7.421122   8.536031
#
#                                  PA0009    PA0010        ...           PA5562  \
# 05_PA14000-4-2_5-10-07_S2.CEL  9.784684  5.485688        ...         9.730384
# 54375-4-05.CEL                 9.404465  5.684067        ...         9.687607
# AKGlu_plus_nt_7-8-09_s1.CEL    9.523126  5.766331        ...         9.717993
# DB1.CEL                        7.455656  5.696851        ...         8.893659
# DB3.CEL                        7.758598  5.528322        ...         8.923777
#
#                                   PA5563     PA5564     PA5565    PA5566  \
# 05_PA14000-4-2_5-10-07_S2.CEL  10.516061  10.639916   9.746849  5.768592
# 54375-4-05.CEL                 10.199612   9.457152   9.318372  5.523898
# AKGlu_plus_nt_7-8-09_s1.CEL    10.419979  10.164667  10.305005  5.806817
# DB1.CEL                         9.317816   9.128908   8.826819  7.857177
# DB3.CEL                         8.938878   8.481878   7.729931  7.484696
#
#                                  PA5567     PA5568     PA5569     PA5570  \
# 05_PA14000-4-2_5-10-07_S2.CEL  9.224442  11.512176  12.529719  11.804896
# 54375-4-05.CEL                 7.911031  10.828271  11.597643  11.268520
# AKGlu_plus_nt_7-8-09_s1.CEL    8.575730  10.858250  12.255953  11.309662
# DB1.CEL                        9.225789   9.632636  11.243346   8.256929
# DB3.CEL                        8.811391   9.778527  10.699039   8.598856
#
#                                growth_setting_1
# 05_PA14000-4-2_5-10-07_S2.CEL        Planktonic
# 54375-4-05.CEL                       Planktonic
# AKGlu_plus_nt_7-8-09_s1.CEL          Planktonic
# DB1.CEL                                 Biofilm
# DB3.CEL                                 Biofilm
#
# [5 rows x 5550 columns]

# %%
# UMAP embedding of raw gene space data
embedding = umap.UMAP().fit_transform(data_labeled.iloc[:,1:-1])
embedding_df = pd.DataFrame(data=embedding, columns=['1','2'])
embedding_df['metadata'] = list(data_labeled[metadata_field])
print(embedding_df.shape)
embedding_df.head(5)
# Out:
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 3 separate connected components using meta-embedding (experimental)
#   n_components
# (989, 3)
#            1         2    metadata
# 0  10.049127 -6.768223  Planktonic
# 1   9.090592 -2.611556  Planktonic
# 2  10.017388 -6.787139  Planktonic
# 3   5.141237 -0.145042     Biofilm
# 4   5.140284 -0.158960     Biofilm

# %%
# Plot
ggplot(aes(x='1',y='2', color='metadata'), data=embedding_df) + \
        geom_point(alpha=0.5) + \
        scale_color_brewer(type='qual', palette='Set2')
#ggMarginal(fig, type='histogram')
# Out:
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# <ggplot: (8751314284506)>

# %% [markdown]
# ## Plot 0-1 normalized data

# %%
normalized_data_labeled = normalized_data.merge(
    metadata_selected_labeled,
    left_index=True,
    right_index=True,
    how='inner')

print(normalized_data_labeled.shape)
normalized_data_labeled.head(5)
# Out:
# (989, 5550)
#                                  PA0001    PA0002    PA0003    PA0004  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.853357  0.725280  0.640617  0.811465
# 54375-4-05.CEL                 0.778790  0.767873  0.614859  0.907865
# AKGlu_plus_nt_7-8-09_s1.CEL    0.789155  0.729508  0.725913  0.718989
# DB1.CEL                        0.256216  0.461307  0.396341  0.430438
# DB3.CEL                        0.320985  0.452921  0.231726  0.447838
#
#                                  PA0005    PA0006    PA0007    PA0008  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.694460  0.533958  0.158865  0.889579
# 54375-4-05.CEL                 0.398800  0.460849  0.113876  0.761351
# AKGlu_plus_nt_7-8-09_s1.CEL    0.530160  0.466327  0.079507  0.731643
# DB1.CEL                        0.398933  0.379887  0.652586  0.569757
# DB3.CEL                        0.335848  0.379614  0.252038  0.518413
#
#                                  PA0009    PA0010        ...           PA5562  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.884945  0.176558        ...         0.702785
# 54375-4-05.CEL                 0.801740  0.222709        ...         0.694387
# AKGlu_plus_nt_7-8-09_s1.CEL    0.827707  0.241847        ...         0.700352
# DB1.CEL                        0.375272  0.225683        ...         0.538515
# DB3.CEL                        0.441566  0.186477        ...         0.544428
#
#                                  PA5563    PA5564    PA5565    PA5566  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.790965  0.893249  0.789939  0.164157
# 54375-4-05.CEL                 0.733186  0.639074  0.681204  0.110301
# AKGlu_plus_nt_7-8-09_s1.CEL    0.773422  0.791118  0.931585  0.172570
# DB1.CEL                        0.572184  0.568535  0.556461  0.623840
# DB3.CEL                        0.502996  0.429489  0.278100  0.541859
#
#                                  PA5567    PA5568    PA5569    PA5570  \
# 05_PA14000-4-2_5-10-07_S2.CEL  0.970470  0.887472  0.900484  0.880012
# 54375-4-05.CEL                 0.619554  0.747656  0.749893  0.805374
# AKGlu_plus_nt_7-8-09_s1.CEL    0.797148  0.753785  0.856253  0.811099
# DB1.CEL                        0.970830  0.503223  0.692651  0.386309
# DB3.CEL                        0.860111  0.533048  0.604709  0.433888
#
#                                growth_setting_1
# 05_PA14000-4-2_5-10-07_S2.CEL        Planktonic
# 54375-4-05.CEL                       Planktonic
# AKGlu_plus_nt_7-8-09_s1.CEL          Planktonic
# DB1.CEL                                 Biofilm
# DB3.CEL                                 Biofilm
#
# [5 rows x 5550 columns]

# %%
# UMAP embedding of raw gene space data
embedding_normalized = umap.UMAP().fit_transform(normalized_data_labeled.iloc[:,1:-1])
embedding_normalized_df = pd.DataFrame(data=embedding_normalized, columns=['1','2'])
embedding_normalized_df['metadata'] = list(normalized_data_labeled[metadata_field])
print(embedding_normalized_df.shape)
embedding_normalized_df.head(5)
# Out:
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 4 separate connected components using meta-embedding (experimental)
#   n_components
# (989, 3)
#           1         2    metadata
# 0  7.032589  5.991780  Planktonic
# 1  7.506773  1.303722  Planktonic
# 2  6.929123  6.095315  Planktonic
# 3  4.911580 -1.644396     Biofilm
# 4  4.867271 -1.678757     Biofilm

# %%
# Plot
ggplot(aes(x='1',y='2', color='metadata'), data=embedding_normalized_df) + \
    geom_point(alpha=0.5) + \
    scale_color_brewer(type='qual', palette='Set2')
# Out:
# /home/alexandra/anaconda3/envs/pytorch_cyclegan/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# <ggplot: (8751302597012)>
